# %% [markdown]
# # Project: Fake News Detection Through Natural Language Processing
#
# ## ML1010 - Group JSMCJ - Project Proposal
#
# ### Part 1: Data preparation
# ### Part 2: Exploratory Data Analysis
# ### Part 3: Data Normalization
# ### Part 4: Feature Engineering
# ### Part 5: Modeling

# %% [markdown]
# ## Part 1: Data preparation

# %% [markdown]
# ### Import libraries and data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

# %% [markdown]
# ## Real News Dataset preparation

# %% [markdown]
# Reading data from the csv files

# %%
df1 = pd.read_csv("/Users/Julia/Desktop/ML1010_Group_Project/all-the-news/articles1.csv")
df2 = pd.read_csv("/Users/Julia/Desktop/ML1010_Group_Project/all-the-news/articles2.csv")
df3 = pd.read_csv("/Users/Julia/Desktop/ML1010_Group_Project/all-the-news/articles3.csv")

# %% [markdown]
# We have a dataset of fake news that was collected in November 2016 (source: https://www.kaggle.com/mrisdal/fake-news/home). For our dataset of real news, we want to collect news articles that were published from October to December of 2016. That gives us ample data points we can use to build classification models.

# %%
df1 = df1.loc[df1['year'] == 2016.0]
df1 = df1.loc[df1['month'].isin([10.0,11.0,12.0])]
df1.head(10)
# Out:
#       Unnamed: 0     id                                              title  \
# 0              0  17283  House Republicans Fret About Winning Their Hea...
# 8              8  17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9              9  17292  Calling on Angels While Enduring the Trials of...
# 2547        2547  20127  U.S. Plans to Step Up Military Campaign Agains...
# 2551        2551  20131  272 Slaves Were Sold to Save Georgetown. What ...
# 2561        2561  20142  Among Travelers and Commuters, the Homeless St...
# 2575        2575  20157  Bus Bombing in Jerusalem Wounds 21 - The New Y...
# 2581        2581  20164  Syria Cease-Fire Crumbles as Bombings Kill Doz...
# 2583        2583  20166          Iceland’s Water Cure - The New York Times
# 2592        2592  20175  Get to Know the Historical Figures on the $5, ...
#
#          publication                                    author        date  \
# 0     New York Times                                Carl Hulse  2016-12-31
# 8     New York Times                          Katherine Rosman  2016-12-31
# 9     New York Times                               Andy Newman  2016-12-31
# 2547  New York Times       Michael S. Schmidt and Eric Schmitt  2016-12-21
# 2551  New York Times                          Rachel L. Swarns  2016-12-15
# 2561  New York Times                           Corey Kilgannon  2016-10-14
# 2575  New York Times                           Isabel Kershner  2016-10-19
# 2581  New York Times                              Anne Barnard  2016-10-20
# 2583  New York Times                                  Dan Kois  2016-10-12
# 2592  New York Times  Julie Hirschfeld Davis and Jada F. Smith  2016-12-18
#
#         year  month  url                                            content
# 0     2016.0   12.0  NaN  WASHINGTON  —   Congressional Republicans have...
# 8     2016.0   12.0  NaN  Just how   is Hillary Kerr, the    founder of ...
# 9     2016.0   12.0  NaN  Angels are everywhere in the Muñiz family’s ap...
# 2547  2016.0   12.0  NaN  ABU DHABI, United Arab Emirates  —   The Obama...
# 2551  2016.0   12.0  NaN  WASHINGTON  —   The human cargo was loaded on ...
# 2561  2016.0   10.0  NaN  Wilson Silva said he knew the homeless situati...
# 2575  2016.0   10.0  NaN  JERUSALEM  —   A bomb exploded on a bus in Jer...
# 2581  2016.0   10.0  NaN  BEIRUT, Lebanon  —   For 38 straight days, the...
# 2583  2016.0   10.0  NaN  On a frigid February day in Reykjavik, I stood...
# 2592  2016.0   12.0  NaN  WASHINGTON  —   The Treasury Department announ...

# %%
df2 = df2.loc[df2['year'] == 2016.0]
df2 = df2.loc[df2['month'].isin([10.0,11.0,12.0])]
df2.head(10)
# Out:
#       Unnamed: 0     id                                              title  \
# 3654       56963  78255                     Trump Time Capsule #124: Taxes
# 3655       56964  78256           What Do You Know ... About Human Organs?
# 3656       56965  78259       Track of the Day: ’Mary’s Song’ by Nick Cave
# 3657       56966  78260        Track of the Day: ’Baba O’Riley’ by The Who
# 3658       56967  78261                 Quoted: The Uphill Battles Edition
# 3659       56968  78262   Track of the Day: ’Twin Falls’ by Built to Spill
# 3660       56969  78263             Trump Time Capsule #125: Willie Horton
# 3661       56970  78264  Trump Time Capsule #126: My Brush With History...
# 3662       56971  78265  You Think the Campaign Is Bad? Just Wait Until...
# 3663       56972  78266                 Must Political Stagecraft Be Evil?
#
#      publication                author        date    year  month  url  \
# 3654    Atlantic         James Fallows  2016-10-02  2016.0   10.0  NaN
# 3655    Atlantic  Rosa Inocencio Smith  2016-10-01  2016.0   10.0  NaN
# 3656    Atlantic        Chris Bodenner  2016-10-02  2016.0   10.0  NaN
# 3657    Atlantic        Chris Bodenner  2016-10-01  2016.0   10.0  NaN
# 3658    Atlantic  Rosa Inocencio Smith  2016-10-01  2016.0   10.0  NaN
# 3659    Atlantic        Chris Bodenner  2016-10-03  2016.0   10.0  NaN
# 3660    Atlantic         James Fallows  2016-10-03  2016.0   10.0  NaN
# 3661    Atlantic         James Fallows  2016-10-04  2016.0   10.0  NaN
# 3662    Atlantic         James Fallows  2016-10-04  2016.0   10.0  NaN
# 3663    Atlantic         Matt Thompson  2016-10-04  2016.0   10.0  NaN
#
#                                                 content
# 3654  People will look back on this era in our histo...
# 3655  Each week, we collect the most surprising fact...
# 3656  An ongoing collection from readers of the song...
# 3657  , A   reader, Tim, floats an idea: Inspired by...
# 3658  An ongoing collection of the best things we he...
# 3659  A   reader, Adam Feiges, floats an idea: I hav...
# 3660  People will look back on this era in our histo...
# 3661  People will look back on this era in our histo...
# 3662  An ongoing reader discussion led by James Fall...
# 3663  Megan Garber leads an ongoing reader discussio...

# %%
df3 = df3.loc[df3['year'] == 2016.0]
df3 = df3.loc[df3['month'].isin([10.0,11.0,12.0])]
df3.head(10)
# Out:
#     Unnamed: 0      id                                              title  \
# 2       103461  151910  My grandmother’s death saved me from a life of...
# 3       103462  151911  I feared my life lacked meaning. Cancer pushed...
# 5       103464  151914  My dad’s Reagan protests inspire me to stand u...
# 8       103467  151917  NSA contractor arrested for alleged theft of t...
# 9       103468  151918  Donald Trump to dissolve his charitable founda...
# 11      103470  151920  The strange case of Pamela Anderson’s news-hog...
# 14      103473  151924  Bad moms: why messy motherhood is finally bein...
# 16      103475  151926  ’Trust can be restored’: Icelanders on their p...
# 26      103485  151938  Twitter to conclude sale negotiations this mon...
# 27      103486  151939  Is our world a simulation? Why some scientists...
#
#    publication             author        date    year  month  \
# 2     Guardian      Robert Pendry  2016-10-31  2016.0   10.0
# 3     Guardian     Bradford Frost  2016-11-26  2016.0   11.0
# 5     Guardian  Steven W Thrasher  2016-11-28  2016.0   11.0
# 8     Guardian     Ewen MacAskill  2016-10-05  2016.0   10.0
# 9     Guardian         Ben Jacobs  2016-12-24  2016.0   12.0
# 11    Guardian                NaN  2016-10-17  2016.0   10.0
# 14    Guardian      Lara Williams  2016-10-02  2016.0   10.0
# 16    Guardian   Guardian readers  2016-10-29  2016.0   10.0
# 26    Guardian                NaN  2016-10-05  2016.0   10.0
# 27    Guardian       Olivia Solon  2016-10-11  2016.0   10.0
#
#                                                   url  \
# 2   https://www.theguardian.com/commentisfree/2016...
# 3   https://www.theguardian.com/commentisfree/2016...
# 5   https://www.theguardian.com/commentisfree/2016...
# 8   https://www.theguardian.com/us-news/2016/oct/0...
# 9   https://www.theguardian.com/us-news/2016/dec/2...
# 11  https://www.theguardian.com/media/shortcuts/20...
# 14  https://www.theguardian.com/tv-and-radio/2016/...
# 16  https://www.theguardian.com/world/2016/oct/29/...
# 26  https://www.theguardian.com/technology/2016/oc...
# 27  https://www.theguardian.com/technology/2016/oc...
#
#                                               content
# 2   Debt: $20, 000, Source: College, credit cards,...
# 3   It was late. I was drunk, nearing my 35th birt...
# 5   I have been battling depression and sleeplessn...
# 8   The FBI has arrested a National Security Agenc...
# 9   Donald Trump announced on Saturday that he wil...
# 11  Name: Pamela Anderson. Age: 49. Occupation: De...
# 14  Better Things opens with its protagonist, Sam ...
# 16  Halldora was born and raised in Iceland and cu...
# 26  Twitter has told potential acquirers it is see...
# 27  When Elon Musk isn’t outlining plans to use hi...

# %% [markdown]
# Now we want to examine the various publications in each csv file.

# %%
publications1 = np.unique(df1["publication"].values)
publications2 = np.unique(df2["publication"].values)
publications3 = np.unique(df3["publication"].values)
print(publications1)
print(publications2)
print(publications3)
# Out:
# ['Atlantic' 'Breitbart' 'Business Insider' 'CNN' 'New York Times']
# ['Atlantic' 'Buzzfeed News' 'Fox News' 'Guardian' 'National Review'
#  'New York Post' 'Talking Points Memo']
# ['Guardian' 'NPR' 'Reuters' 'Vox' 'Washington Post']

# %% [markdown]
# We want to select several reputable publications for the real news dataset, as well as several other 'less-reputable' publications, in order to have a more balanced representation of news published by a real news publication company. Those included are listed below.
#
# We used a media bias/fact check website (source: https://mediabiasfactcheck.com/) to assess each news publication company. The results are below (each company is rated on their factual reporting).
#
# Factual reporting:
# - Very High: reuters, npr
# - High: new york times, atlantic, guardian, washington post, vox
# - Mixed: fox news, cnn, national review

# %%
df = pd.concat([df1,df2,df3])
df = df.loc[df['publication'].isin(['New York Times', 'CNN','Atlantic','Fox News','Guardian','National Review','NPR','Reuters', 'Vox','Washington Post'])]
df
# Out:
#        Unnamed: 0      id                                              title  \
# 0               0   17283  House Republicans Fret About Winning Their Hea...
# 8               8   17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9               9   17292  Calling on Angels While Enduring the Trials of...
# 2547         2547   20127  U.S. Plans to Step Up Military Campaign Agains...
# 2551         2551   20131  272 Slaves Were Sold to Save Georgetown. What ...
# 2561         2561   20142  Among Travelers and Commuters, the Homeless St...
# 2575         2575   20157  Bus Bombing in Jerusalem Wounds 21 - The New Y...
# 2607   DETROIT  —   Fiat Chrysler said on Friday that...
# 2609   Prince wasn’t someone many people said no to. ...
# 2610   Prince, the songwriter, singer, producer,   st...
# 2613   As a child, you played Laura Ingalls Wilder in...
# 2616   GARDEN CITY, N. Y.  —   Mary Crosson, a housin...
# 2619   PITTSBURGH  —    There would be no   magic for...
# 2621   LONDON  —   Lady Elizabeth Anson, Queen Elizab...
# 2622   WYOMING, Del.  —   By his own account, Toby Lo...
# 2624   WARWICK, R. I.  —   Most years, the presidenti...
# 2629   The reaction has been swift. The singer Bryan ...
# 2634   Roger Goodell, the most powerful man in profes...
# 2643   HONG KONG  —   Since 2010, Yu Kai has followed...
# 2644   On a muggy afternoon in April, Angelina Iles, ...
# 2653   No one can know for sure what was in the mind ...
# 2666   “Your Top 5 favorite sandwiches, in order, ple...
# 2667   It’s a   tradition for politicians to deny any...
# 2669   Two months ago, across an   table in a factory...
# 2671   BRASÍLIA  —   They were idealists, united in t...
# 2672   SANKHU, Nepal  —   As the anniversary of Nepal...
# ...                                                  ...
# 42541       Our greatest fear for 2017 and the Trump ...
# 42542   A   will take effect across much of Syria fro...
# 42543       There is an old saying in politics: The m...
# 42544       The truck attack on a Christmas market in...
# 42545       Frigid air will grip an unusually large p...
# 42546       A backlash to globalization appears to be...
# 42547       For decades, the data on median household...
# 42548     Far Side cartoons, Ansel Adams landscapes, ...
# 42549       Somewhere between Texas and Alabama, some...
# 42550    MOSCOW  —   On a day when everyone expected ...
# 42551         Donald Trump on Friday expressed his ap...
# 42552       Maria Zakharova, a spokeswoman for the Ru...
# 42553       With just one day to go before he leaves ...
# 42554   Indiana lawmakers originally promoted the sta...
# 42555         PHOENIX, Ariz.  —   This was supposed t...
# 42556        The year started ominously, with a big f...
# 42557         Donald Trump, having dismissed as “ridi...
# 42558       President Obama’s decision to abstain at ...
# 42559    CHARLOTTESVILLE   I came here during the hol...
# 42560       Torn between impatience for 2016 to be ov...
# 42561     Naureen Shah is director of security and hu...
# 42562   ALTHOUGH PRESIDENT Obama’s sanctions against ...
# 42563    BRUSSELS  —   British Prime Minister Theresa...
# 42564     BEIJING  —   China promised Friday to halt ...
# 42565       The decision was not an easy one, wrote J...
# 42566           Uber driver Keith Avila picked up a p...
# 42567           Crews on Friday continued to search L...
# 42568       When the Obama administration announced a...
# 42569       This story has been updated. A new law in...
# 42570       The nation’s first recreational marijuana...
#
# [15712 rows x 10 columns]

# %% [markdown]
# Renaming 'content' column as 'text', to match the name of the text news variable from the fake news dataset

# %%
df = df.rename(columns={'content': 'text'})

# %%
df.head()
# Out:
#       Unnamed: 0     id                                              title  \
# 0              0  17283  House Republicans Fret About Winning Their Hea...
# 8              8  17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9              9  17292  Calling on Angels While Enduring the Trials of...
# 2547        2547  20127  U.S. Plans to Step Up Military Campaign Agains...
# 2551        2551  20131  272 Slaves Were Sold to Save Georgetown. What ...
#
#          publication                               author        date    year  \
# 0     New York Times                           Carl Hulse  2016-12-31  2016.0
# 8     New York Times                     Katherine Rosman  2016-12-31  2016.0
# 9     New York Times                          Andy Newman  2016-12-31  2016.0
# 2547  New York Times  Michael S. Schmidt and Eric Schmitt  2016-12-21  2016.0
# 2551  New York Times                     Rachel L. Swarns  2016-12-15  2016.0
#
#       month  url                                               text
# 0      12.0  NaN  WASHINGTON  —   Congressional Republicans have...
# 8      12.0  NaN  Just how   is Hillary Kerr, the    founder of ...
# 9      12.0  NaN  Angels are everywhere in the Muñiz family’s ap...
# 2547   12.0  NaN  ABU DHABI, United Arab Emirates  —   The Obama...
# 2551   12.0  NaN  WASHINGTON  —   The human cargo was loaded on ...

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# title           object
# publication     object
# author          object
# date            object
# year           float64
# month          float64
# url             object
# text            object
# dtype: object

# %%
df['month'] = pd.DataFrame(df['month'])

# %%
df['month'].dtypes
# Out:
# dtype('float64')

# %%
df['month'] = df['month'].astype(int)

# %%
df['month'].dtypes
# Out:
# dtype('int64')

# %%
df['month'].head()
# Out:
# 0       12
# 8       12
# 9       12
# 2547    12
# 2551    12
# Name: month, dtype: int64

# %%
df.head()
# Out:
#       Unnamed: 0     id                                              title  \
# 0              0  17283  House Republicans Fret About Winning Their Hea...
# 8              8  17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9              9  17292  Calling on Angels While Enduring the Trials of...
# 2547        2547  20127  U.S. Plans to Step Up Military Campaign Agains...
# 2551        2551  20131  272 Slaves Were Sold to Save Georgetown. What ...
#
#          publication                               author        date    year  \
# 0     New York Times                           Carl Hulse  2016-12-31  2016.0
# 8     New York Times                     Katherine Rosman  2016-12-31  2016.0
# 9     New York Times                          Andy Newman  2016-12-31  2016.0
# 2547  New York Times  Michael S. Schmidt and Eric Schmitt  2016-12-21  2016.0
# 2551  New York Times                     Rachel L. Swarns  2016-12-15  2016.0
#
#       month  url                                               text
# 0        12  NaN  WASHINGTON  —   Congressional Republicans have...
# 8        12  NaN  Just how   is Hillary Kerr, the    founder of ...
# 9        12  NaN  Angels are everywhere in the Muñiz family’s ap...
# 2547     12  NaN  ABU DHABI, United Arab Emirates  —   The Obama...
# 2551     12  NaN  WASHINGTON  —   The human cargo was loaded on ...

# %%
# Selecting only columns that are common to the fake news dataset
real_news = df[['id', 'author', 'title', 'text', 'date', 'month', 'url']]

# %%
# Creating a Target variable called "fake".  It will have a value of 0 for real news and 1 for fake news
real_news["fake"] = 0
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
real_news.head()
# Out:
#          id                               author  \
# 0     17283                           Carl Hulse
# 8     17291                     Katherine Rosman
# 9     17292                          Andy Newman
# 2547  20127  Michael S. Schmidt and Eric Schmitt
# 2551  20131                     Rachel L. Swarns
#
#                                                   title  \
# 0     House Republicans Fret About Winning Their Hea...
# 8     First, a Mixtape. Then a Romance. - The New Yo...
# 9     Calling on Angels While Enduring the Trials of...
# 2547  U.S. Plans to Step Up Military Campaign Agains...
# 2551  272 Slaves Were Sold to Save Georgetown. What ...
#
#                                                    text        date  month  \
# 0     WASHINGTON  —   Congressional Republicans have...  2016-12-31     12
# 8     Just how   is Hillary Kerr, the    founder of ...  2016-12-31     12
# 9     Angels are everywhere in the Muñiz family’s ap...  2016-12-31     12
# 2547  ABU DHABI, United Arab Emirates  —   The Obama...  2016-12-21     12
# 2551  WASHINGTON  —   The human cargo was loaded on ...  2016-12-15     12
#
#       url  fake
# 0     NaN     0
# 8     NaN     0
# 9     NaN     0
# 2547  NaN     0
# 2551  NaN     0

# %%
real_news.columns
# Out:
# Index(['id', 'author', 'title', 'text', 'date', 'month', 'url', 'fake'], dtype='object')

# %%
real_news.shape
# Out:
# (15712, 8)

# %%
# Saving data frame as a new csv file called "real_news.csv".
real_news.to_csv('real_news.csv', encoding='utf-8')

# %% [markdown]
# ## Fake News Dataset preparation

# %%
fake = pd.read_csv("/Users/Julia/Desktop/ML1010_Group_Project/all-the-news/fake.csv")

# %%
fake.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# 2  Red State : \nFox News Sunday reported this mo...  english
# 3  Email Kayla Mueller was a prisoner and torture...  english
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
#
#                          crawled             site_url country  domain_rank  \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US      25689.0
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US      25689.0
# 2  2016-10-31T01:41:49.479+02:00  100percentfedup.com      US      25689.0
# 3  2016-11-01T15:46:26.304+02:00  100percentfedup.com      US      25689.0
# 4  2016-11-01T23:59:42.266+02:00  100percentfedup.com      US      25689.0
#
#                                         thread_title  spam_score  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...       0.000
# 1  Re: Why Did Attorney General Loretta Lynch Ple...       0.000
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...       0.000
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...       0.068
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...       0.865
#
#                                         main_img_url  replies_count  \
# 0  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 1  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 2  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 3  http://100percentfedup.com/wp-content/uploads/...              0
# 4  http://100percentfedup.com/wp-content/uploads/...              0
#
#    participants_count  likes  comments  shares  type
# 0                   1      0         0       0  bias
# 1                   1      0         0       0  bias
# 2                   1      0         0       0  bias
# 3                   0      0         0       0  bias
# 4                   0      0         0       0  bias

# %%
fake.shape
# Out:
# (12999, 20)

# %%
fake.columns
# Out:
# Index(['uuid', 'ord_in_thread', 'author', 'published', 'title', 'text',
#        'language', 'crawled', 'site_url', 'country', 'domain_rank',
#        'thread_title', 'spam_score', 'main_img_url', 'replies_count',
#        'participants_count', 'likes', 'comments', 'shares', 'type'],
#       dtype='object')

# %%
english_fake_news = fake[fake["language"] == "english"]

# %%
english_fake_news.shape
# Out:
# (12403, 20)

# %%
all_fake_news = english_fake_news[english_fake_news["type"] == "bs"]

# %%
all_fake_news.shape
# Out:
# (10900, 20)

# %%
all_fake_news.head()
# Out:
#                                         uuid  ord_in_thread  \
# 59  b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9              0
# 60  03905a0f06cb711190aad3934af253a0e1c00a83              1
# 61  42c16d3818e64ff4632409cafd309c22df530ac1              2
# 62  336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f              3
# 63  ea086a28e0bbafcd9fbaabd728920337371d4876              4
#
#                               author                      published  \
# 59  tokyowashi (noreply@blogger.com)  2016-10-27T06:14:00.000+03:00
# 60                         Anonymous  2016-10-26T23:12:00.000+03:00
# 61                         Anonymous  2016-10-26T22:48:00.000+03:00
# 62                         Anonymous  2016-10-26T22:35:00.000+03:00
# 63                         Anonymous  2016-10-26T22:19:00.000+03:00
#
#                                                 title  \
# 59  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
#
#                                                  text language  \
# 59  United States Marine Field McConnell  Plum Cit...  english
# 60  So ,you have Rothschild banksters and British ...  english
# 61  Here is the problem . The USA constitution sta...  english
# 62  There is plenty of proof the machines are rigg...  english
# 63  Trump has an excuse now to audit any vote with...  english
#
#                           crawled        site_url country  domain_rank  \
# 59  2016-10-27T07:37:58.775+03:00  abeldanger.net      US          NaN
# 60  2016-10-27T07:37:58.893+03:00  abeldanger.net      US          NaN
# 61  2016-10-27T07:37:58.902+03:00  abeldanger.net      US          NaN
# 62  2016-10-27T07:37:58.915+03:00  abeldanger.net      US          NaN
# 63  2016-10-27T07:37:58.925+03:00  abeldanger.net      US          NaN
#
#                                          thread_title  spam_score  \
# 59  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...         0.0
# 60  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...         0.0
# 61  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...         0.0
# 62  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...         0.0
# 63  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...         0.0
#
#    main_img_url  replies_count  participants_count  likes  comments  shares  \
# 59          NaN              5                   1      0         0       0
# 60          NaN              5                   1      0         0       0
# 61          NaN              5                   1      0         0       0
# 62          NaN              5                   1      0         0       0
# 63          NaN              5                   1      0         0       0
#
#    type
# 59   bs
# 60   bs
# 61   bs
# 62   bs
# 63   bs

# %%
# Count missing values
all_fake_news.isnull().sum()
# Out:
# uuid                     0
# ord_in_thread            0
# author                1731
# published                0
# title                  573
# text                     0
# language                 0
# crawled                  0
# site_url                 0
# country                176
# domain_rank           3990
# thread_title            12
# spam_score               0
# main_img_url          3310
# replies_count            0
# participants_count       0
# likes                    0
# comments                 0
# shares                   0
# type                     0
# dtype: int64

# %%
# Visual observation of the CSV file reveals that 'title' = 'thread_title'.  
# Therefore, for the cases where title is missing, we can impute the thread_title. 
# We will also replace the Nulls in 'text' with blanks ('')
if all_fake_news['title'] is None:
    all_fake_news['title'] = all_fake_news['thread_title']
else:
    all_fake_news['title'] is None and all_fake_news['thread_title'] is None
    all_fake_news['title'] = ''
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
all_fake_news['crawled'].head()
# Out:
# 59   2016-10-27 04:37:58.775
# 60   2016-10-27 04:37:58.893
# 61   2016-10-27 04:37:58.902
# 62   2016-10-27 04:37:58.915
# 63   2016-10-27 04:37:58.925
# Name: crawled, dtype: datetime64[ns]

# %%
all_fake_news['crawled'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
all_fake_news['month'] = all_fake_news['crawled'].dt.month
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
all_fake_news.head()
# Out:
#                                         uuid  ord_in_thread  \
# 59  b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9              0
# 60  03905a0f06cb711190aad3934af253a0e1c00a83              1
# 61  42c16d3818e64ff4632409cafd309c22df530ac1              2
# 62  336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f              3
# 63  ea086a28e0bbafcd9fbaabd728920337371d4876              4
#
#                               author                      published title  \
# 59  tokyowashi (noreply@blogger.com)  2016-10-27T06:14:00.000+03:00
# 60                         Anonymous  2016-10-26T23:12:00.000+03:00
# 61                         Anonymous  2016-10-26T22:48:00.000+03:00
# 62                         Anonymous  2016-10-26T22:35:00.000+03:00
# 63                         Anonymous  2016-10-26T22:19:00.000+03:00
#
#                                                  text language  \
# 59  United States Marine Field McConnell  Plum Cit...  english
# 60  So ,you have Rothschild banksters and British ...  english
# 61  Here is the problem . The USA constitution sta...  english
# 62  There is plenty of proof the machines are rigg...  english
# 63  Trump has an excuse now to audit any vote with...  english
#
#                    crawled        site_url country  ...   \
# 59 2016-10-27 04:37:58.775  abeldanger.net      US  ...
# 60 2016-10-27 04:37:58.893  abeldanger.net      US  ...
# 61 2016-10-27 04:37:58.902  abeldanger.net      US  ...
# 62 2016-10-27 04:37:58.915  abeldanger.net      US  ...
# 63 2016-10-27 04:37:58.925  abeldanger.net      US  ...
#
#                                          thread_title spam_score  \
# 59  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...        0.0
# 60  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...        0.0
# 61  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...        0.0
# 62  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...        0.0
# 63  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...        0.0
#
#     main_img_url replies_count  participants_count  likes  comments  shares  \
# 59           NaN             5                   1      0         0       0
# 60           NaN             5                   1      0         0       0
# 61           NaN             5                   1      0         0       0
# 62           NaN             5                   1      0         0       0
# 63           NaN             5                   1      0         0       0
#
#     type month
# 59    bs    10
# 60    bs    10
# 61    bs    10
# 62    bs    10
# 63    bs    10
#
# [5 rows x 21 columns]

# %%
all_fake_news.columns
# Out:
# Index(['uuid', 'ord_in_thread', 'author', 'published', 'title', 'text',
#        'language', 'crawled', 'site_url', 'country', 'domain_rank',
#        'thread_title', 'spam_score', 'main_img_url', 'replies_count',
#        'participants_count', 'likes', 'comments', 'shares', 'type', 'month'],
#       dtype='object')

# %%
real_news.columns
# Out:
# Index(['id', 'author', 'title', 'text', 'date', 'month', 'url', 'fake'], dtype='object')

# %%
# Renaming columns to have same name as columns of the 'real' news dataset
all_fake_news = all_fake_news.rename(columns={'uuid': 'id', 'crawled': 'date', 'site_url': 'url'})

# %%
all_fake_news.columns
# Out:
# Index(['id', 'ord_in_thread', 'author', 'published', 'title', 'text',
#        'language', 'date', 'url', 'country', 'domain_rank', 'thread_title',
#        'spam_score', 'main_img_url', 'replies_count', 'participants_count',
#        'likes', 'comments', 'shares', 'type', 'month'],
#       dtype='object')

# %%
# Selecting only columns that are common with the real news dataset
fake_news = all_fake_news[['id', 'author', 'title', 'text', 'date', 'month','url']]

# %%
fake_news.columns
# Out:
# Index(['id', 'author', 'title', 'text', 'date', 'month', 'url'], dtype='object')

# %%
fake_news.shape
# Out:
# (10900, 7)

# %%
# Creating a Target variable called "fake".  It will have a value of 0 for real news and 1 for fake news
fake_news["fake"] = 1
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fake_news.shape
# Out:
# (10900, 8)

# %%
fake_news.head()
# Out:
#                                           id  \
# 59  b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9
# 60  03905a0f06cb711190aad3934af253a0e1c00a83
# 61  42c16d3818e64ff4632409cafd309c22df530ac1
# 62  336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f
# 63  ea086a28e0bbafcd9fbaabd728920337371d4876
#
#                               author title  \
# 59  tokyowashi (noreply@blogger.com)
# 60                         Anonymous
# 61                         Anonymous
# 62                         Anonymous
# 63                         Anonymous
#
#                                                  text                    date  \
# 59  United States Marine Field McConnell  Plum Cit... 2016-10-27 04:37:58.775
# 60  So ,you have Rothschild banksters and British ... 2016-10-27 04:37:58.893
# 61  Here is the problem . The USA constitution sta... 2016-10-27 04:37:58.902
# 62  There is plenty of proof the machines are rigg... 2016-10-27 04:37:58.915
# 63  Trump has an excuse now to audit any vote with... 2016-10-27 04:37:58.925
#
#     month             url  fake
# 59     10  abeldanger.net     1
# 60     10  abeldanger.net     1
# 61     10  abeldanger.net     1
# 62     10  abeldanger.net     1
# 63     10  abeldanger.net     1

# %%
# Saving data frame as a new csv file called "fake_news.csv".
fake_news.to_csv('fake_news.csv', encoding='utf-8')

# %% [markdown]
# ### Merging real_news and fake_news datasets

# %%
frames = [real_news, fake_news]

# %%
real_fake = pd.concat(frames)

# %%
real_fake.columns
# Out:
# Index(['id', 'author', 'title', 'text', 'date', 'month', 'url', 'fake'], dtype='object')

# %%
real_fake.shape
# Out:
# (26612, 8)

# %%
real_fake.head()
# Out:
#          id                               author  \
# 0     17283                           Carl Hulse
# 8     17291                     Katherine Rosman
# 9     17292                          Andy Newman
# 2547  20127  Michael S. Schmidt and Eric Schmitt
# 2551  20131                     Rachel L. Swarns
#
#                                                   title  \
# 0     House Republicans Fret About Winning Their Hea...
# 8     First, a Mixtape. Then a Romance. - The New Yo...
# 9     Calling on Angels While Enduring the Trials of...
# 2547  U.S. Plans to Step Up Military Campaign Agains...
# 2551  272 Slaves Were Sold to Save Georgetown. What ...
#
#                                                    text        date  month  \
# 0     WASHINGTON  —   Congressional Republicans have...  2016-12-31     12
# 8     Just how   is Hillary Kerr, the    founder of ...  2016-12-31     12
# 9     Angels are everywhere in the Muñiz family’s ap...  2016-12-31     12
# 2547  ABU DHABI, United Arab Emirates  —   The Obama...  2016-12-21     12
# 2551  WASHINGTON  —   The human cargo was loaded on ...  2016-12-15     12
#
#       url  fake
# 0     NaN     0
# 8     NaN     0
# 9     NaN     0
# 2547  NaN     0
# 2551  NaN     0

# %%
# converting target variable ("fake" column) to "category" (factor)
real_fake['fake'] = real_fake.fake.astype('category')

# %%
real_fake.dtypes
# Out:
# id          object
# author      object
# title       object
# text        object
# date        object
# month        int64
# url         object
# fake      category
# dtype: object

# %% [markdown]
# ### Saving data frame as a new csv file called "real_fake_news.csv".

# %%
real_fake.to_csv('real_fake_news_v2.csv', encoding='utf-8')

# %% [markdown]
# ## Part 2: Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import scipy.stats as spstats
import datetime
pd.options.mode.chained_assignment = None
plt.style.use('ggplot')
import nltk
# nltk.download('punkt')  ## run this command only if you don't have the 'punkt' package already installed
import spacy
nlp = spacy.load('en', parse = False, tag=False, entity=False)
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
all_news = real_fake

# %%
all_news.head(5)
# Out:
#          id                               author  \
# 0     17283                           Carl Hulse
# 8     17291                     Katherine Rosman
# 9     17292                          Andy Newman
# 2547  20127  Michael S. Schmidt and Eric Schmitt
# 2551  20131                     Rachel L. Swarns
#
#                                                   title  \
# 0     House Republicans Fret About Winning Their Hea...
# 8     First, a Mixtape. Then a Romance. - The New Yo...
# 9     Calling on Angels While Enduring the Trials of...
# 2547  U.S. Plans to Step Up Military Campaign Agains...
# 2551  272 Slaves Were Sold to Save Georgetown. What ...
#
#                                                    text        date  month  \
# 0     WASHINGTON  —   Congressional Republicans have...  2016-12-31     12
# 8     Just how   is Hillary Kerr, the    founder of ...  2016-12-31     12
# 9     Angels are everywhere in the Muñiz family’s ap...  2016-12-31     12
# 2547  ABU DHABI, United Arab Emirates  —   The Obama...  2016-12-21     12
# 2551  WASHINGTON  —   The human cargo was loaded on ...  2016-12-15     12
#
#       url fake
# 0     NaN    0
# 8     NaN    0
# 9     NaN    0
# 2547  NaN    0
# 2551  NaN    0

# %% [markdown]
# ## Dataframe dimensions and data types

# %%
all_news.shape
# Out:
# (26612, 8)

# %%
all_news.dtypes
# Out:
# id          object
# author      object
# title       object
# text        object
# date        object
# month        int64
# url         object
# fake      category
# dtype: object

# %%
# converting month variable to "category" (factor)
all_news['month'] = all_news.month.astype('category')

# %%
all_news.dtypes
# Out:
# id          object
# author      object
# title       object
# text        object
# date        object
# month     category
# url         object
# fake      category
# dtype: object

# %% [markdown]
# ## Summary statistics

# %%
all_news.describe()
# Out:
#                                               id author  title   text  \
# count                                      26612  23136  26612  26612
# unique                                     26612   6298  15705  26141
# top     9c6f9c9f2ba6764fa82f4e55d4cb43b2292f7b20  admin
# freq                                           1    199  10900    104
#
#               date  month      url   fake
# count        26612  26612    22001  26612
# unique       11081      3    11311      2
# top     2016-11-09     11  ijr.com      0
# freq           252  10914      100  15712

# %% [markdown]
# ### Counts categorical data

# %%
all_news['fake'].value_counts()
# Out:
# 0    15712
# 1    10900
# Name: fake, dtype: int64

# %%
all_news['fake'].value_counts().plot(kind='bar')

# %%
all_news['month'].value_counts()
# Out:
# 11    10914
# 10    10385
# 12     5313
# Name: month, dtype: int64

# %%
all_news['month'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Count missing values

# %%
all_news.isnull().sum()
# Author and url have missing values, but they are not relevant features for our analysis.  
# No missing values in titles and text
# Out:
# id           0
# author    3476
# title        0
# text         0
# date         0
# month        0
# url       4611
# fake         0
# dtype: int64

# %% [markdown]
# ## Part 3: Text Normalization

# %% [markdown]
# ### Preparing Text-only Dataset

# %% [markdown]
# ### Merging title and text for text analysis
#
# For purposes of text mining, we concatenate the title and text of the news article and use this merged field for news text analysis.

# %%
all_text = all_news.title.str.cat(all_news.text, sep=' ')

# %%
all_text.head()
# Out:
# 0       House Republicans Fret About Winning Their Hea...
# 8       First, a Mixtape. Then a Romance. - The New Yo...
# 9       Calling on Angels While Enduring the Trials of...
# 2547    U.S. Plans to Step Up Military Campaign Agains...
# 2551    272 Slaves Were Sold to Save Georgetown. What ...
# Name: title, dtype: object

# %% [markdown]
# ## James, I think Normalization code would go here, before running anything else below.  Plese insert the normalization code here if you agree

# %% [markdown]
# ### Count missing values in the text data

# %%
if all_text is None:
    print(all_text)
# No output - there are no missing values in the text for mining

# %% [markdown]
# ### Save new dataframe as csv

# %%
all_text.to_csv('all_text.csv')

# %% [markdown]
# ## Part 4: Feature Engineering

# %% [markdown]
# ### Tokenization with NLTK

# %%
# Fill any blank fields
all_text.fillna("", inplace=True)

# %%
words = nltk.word_tokenize(" ".join(all_text.tolist()))

# %%
words_df = pd.DataFrame(words)

# %%
words_df.head()
# Out:
#              0
# 0        House
# 1  Republicans
# 2         Fret
# 3        About
# 4      Winning

# %% [markdown]
# ### Cleaning/Stopword removal with NLTK

# %%
from nltk.corpus import stopwords
import string

# cleaning
stop = stopwords.words('english') 
cleanwords = [i for i in words if i not in stop and i.isalpha() and len(i) > 2]

# %% [markdown]
# ### Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# creating wordcloud (i.e., visual representation of text data) 
# the wordcloud displays a list of words, the importance of each beeing shown with font size or color

wordcloud2 = WordCloud(
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=1200,
                          height=1000
                         ).generate(" ".join(cleanwords))


plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Bigram Analysis with NLTK

# %%
# Bigrams (pairs of consecutive written units like letters, syllables, or words)

bigrams = nltk.bigrams(cleanwords)

# %%
# most common bigrams

from collections import Counter

counter = Counter(bigrams)
print(counter.most_common(10))
# Out:
# [(('Donald', 'Trump'), 18558), (('Hillary', 'Clinton'), 13822), (('United', 'States'), 12822), (('New', 'York'), 11405), (('White', 'House'), 6787), (('York', 'Times'), 4456), (('The', 'New'), 3525), (('years', 'ago'), 3325), (('President', 'Obama'), 3105), (('Washington', 'Post'), 3079)]

# %%
num_to_show = 30

labels = [" ".join(e[0]) for e in counter.most_common(num_to_show)]
values = [e[1] for e in counter.most_common(num_to_show)]

indexes = np.arange(len(labels))
width = 1

#plt.bar(indexes, values, width)
#plt.xticks(indexes + width * 0.5, labels, rotation=90)

plt.barh(indexes, values, width)
plt.yticks(indexes + width * 0.2, labels)
plt.show()

# %% [markdown]
# ##  *** ~ Feature engineering - To be completed ~ ***

# %% [markdown]
# ###    Tokenization with other methods: Spacy, tfidf...... other

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# ### Vectorizing Raw Text

# %% [markdown]
# ### ...maybe some Topic Modeling as well
